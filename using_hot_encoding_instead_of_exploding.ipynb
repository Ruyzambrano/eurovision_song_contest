# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import ast

# %% [markdown]
# # Read in Data

# %%
data = pd.read_csv("data/combined_data.csv")

# %%
data.sample(10)
# Out:
#      Country Name Country Code  Year                  Song  \
# 1030      Denmark          DNK  2013        Only Teardrops
# 1189      Estonia          EST  2017                Verona
# 645       Estonia          EST  2003  Eighties Coming Back
# 838     Lithuania          LTU  2008   Nomads in the Night
# 715       Hungary          HUN  2005        Forogj, világ!
# 1033       France          FRA  2013        L'enfer et moi
# 1227      Croatia          HRV  2018                 Crazy
# 61        Finland          FIN  1975        Old Man Fiddle
# 674       Denmark          DNK  2004          Shame on You
# 532         Malta          MLT  1998   The One That I Love
#
#                     Artist       Language  Grand Final Place  \
# 1030     Emmelie de Forest    ['English']                1.0
# 1189  Koit Toome and Laura    ['English']                NaN
# 645                 Ruffus    ['English']               21.0
# 838       Jeronimas Milius    ['English']                NaN
# 715                    NOX  ['Hungarian']               12.0
# 1033    Amandine Bourgeois     ['French']               23.0
# 1227                Franka    ['English']                NaN
# 61           Pihasoittajat    ['English']                7.0
# 674       Tomas Thordarson    ['English']                NaN
# 532                 Chiara    ['English']                3.0
#
#       Grand Final Points  Semifinal  Semifinal Place  ...  \
# 1030               281.0        1.0              1.0  ...
# 1189                 NaN        2.0             14.0  ...
# 645                 14.0        NaN              NaN  ...
# 838                  NaN        2.0             16.0  ...
# 715                 97.0        NaN              5.0  ...
# 1033                14.0        NaN              NaN  ...
# 1227                 NaN        1.0             17.0  ...
# 61                  74.0        NaN              NaN  ...
# 674                  NaN        NaN             13.0  ...
# 532                165.0        NaN              NaN  ...
#
#       People with basic handwashing facilities including soap and water, urban (% of urban population)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Risk premium on lending (lending rate minus treasury bill rate, %)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                            1.587988
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                            2.677500
#
#       Incidence of malaria (per 1,000 population at risk)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Net financial flows, RDB concessional (NFL, current US$)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Financial intermediary services indirectly Measured (FISIM) (constant LCU)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Net financial flows, IMF concessional (NFL, current US$)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Newborns protected against tetanus (%)  \
# 1030                                     NaN
# 1189                                     NaN
# 645                                      NaN
# 838                                      NaN
# 715                                      NaN
# 1033                                     NaN
# 1227                                     NaN
# 61                                       NaN
# 674                                      NaN
# 532                                      NaN
#
#       Net official flows from UN agencies, UNWTO (current US$)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
#       Use of insecticide-treated bed nets (% of under-5 population)
# 1030                                                NaN
# 1189                                                NaN
# 645                                                 NaN
# 838                                                 NaN
# 715                                                 NaN
# 1033                                                NaN
# 1227                                                NaN
# 61                                                  NaN
# 674                                                 NaN
# 532                                                 NaN
#
# [10 rows x 1499 columns]

# %% [markdown]
# ## Format the Languages to be a list

# %%
data["Language"] = data["Language"].str.removeprefix("[").str.removesuffix("]").str.split(",")

# %% [markdown]
# ## Encode the Languages as Binaries

# %%
mlb = MultiLabelBinarizer()
language_encoded = mlb.fit_transform(data['Language'])

# %%
mlb.classes_
# Out:
# array([" 'Albanian'", " 'Antillean Creole'", " 'Arabic'", " 'Armenian'",
#        " 'Bosnian'", " 'Bulgarian'", " 'Catalan'", " 'Corsican'",
#        " 'Crimean Tatar'", " 'Croatian'", " 'Czech'",
#        ' \'English ("Franglais")\'', " 'English'", " 'Finnish'",
#        " 'French'", " 'Georgian'", " 'German'", " 'Greek'", " 'Hebrew'",
#        " 'Hungarian'", " 'Imaginary'", " 'Italian'", " 'Latin'",
#        " 'Lithuanian'", " 'Luxembourgish'", " 'Macedonian'", " 'Maltese'",
#        " 'Northern Sami'", " 'Polish'", " 'Portuguese'", " 'Romani'",
#        " 'Romanian'", " 'Russian'", " 'Slovene'", " 'Spanish'",
#        " 'Srnan Tongo'", " 'Swahili'", " 'Turkish'", " 'Ukrainian'",
#        "'Albanian'", "'Arabic'", "'Armenian'", "'Belarusian'",
#        "'Bosnian'", "'Breton'", "'Bulgarian'", "'Catalan'", "'Corsican'",
#        "'Croatian'", "'Czech'", "'Danish'", "'Dutch'", "'English'",
#        "'Estonian'", "'Finnish'", "'French'", "'Georgian'", "'German'",
#        "'Greek'", "'Hebrew'", "'Hungarian'", "'Icelandic'", "'Imaginary'",
#        "'Irish'", "'Italian'", "'Latvian'", "'Lithuanian'",
#        "'Luxembourgish'", "'Macedonian'", "'Maltese'", "'Montenegrin'",
#        "'Neapolitan'", "'Norwegian'", "'Polish'", "'Portuguese'",
#        "'Romanian'", "'Romansh'", "'Russian'", "'Samogitian'",
#        "'Serbian'", "'Slovak'", "'Slovene'", "'Spanish'", "'Swedish'",
#        "'Turkish'", "'Udmurt'", "'Ukrainian'", "'Viennese'",
#        "'Vorarlbergish'", "'Võro'"], dtype=object)

# %%
language_df = pd.DataFrame(language_encoded, columns=mlb.classes_)

# %%
data = pd.concat([data, language_df], axis=1).drop(columns=['Language'])

# %%
data.sample(10)
# Out:
#         Country Name Country Code  Year  \
# 352         Portugal          PRT  1990
# 756        Lithuania          LTU  2006
# 296          Austria          AUT  1988
# 197      Switzerland          CHE  1982
# 318           Cyprus          CYP  1989
# 980          Albania          ALB  2012
# 584  North Macedonia          MKD  2000
# 39        Luxembourg          LUX  1973
# 906          Croatia          HRV  2010
# 875          Iceland          ISL  2009
#
#                                        Song  \
# 352                        Há sempre alguém
# 756                      We Are the Winners
# 296                          Lisa Mona Lisa
# 197                         Amour on t'aime
# 318  Apopse as vrethume (Απόψε ας βρεθούμε)
# 980                                    Suus
# 584          100% te ljubam (100% те љубам)
# 39                       Tu te reconnaîtras
# 906                             Lako je sve
# 875                             Is It True?
#
#                                  Artist  Grand Final Place  \
# 352                               Nucha               20.0
# 756                           LT United                6.0
# 296                            Wilfried               21.0
# 197                        Arlette Zola                3.0
# 318  Fani Polymeri & Yiannis Savvidakis               11.0
# 980                        Rona Nishliu                5.0
# 584                                 XXL               15.0
# 39                     Anne-Marie David                1.0
# 906                            Feminnem                NaN
# 875                             Yohanna                2.0
#
#      Grand Final Points  Semifinal  Semifinal Place  Semifinal Points  ...  \
# 352                 9.0        NaN              NaN               NaN  ...
# 756               162.0        NaN              5.0             163.0  ...
# 296                 0.0        NaN              NaN               NaN  ...
# 197                97.0        NaN              NaN               NaN  ...
# 318                51.0        NaN              NaN               NaN  ...
# 980               146.0        1.0              2.0             146.0  ...
# 584                29.0        NaN              NaN               NaN  ...
# 39                129.0        NaN              NaN               NaN  ...
# 906                 NaN        2.0             13.0              33.0  ...
# 875               218.0        1.0              1.0             174.0  ...
#
#      'Slovak'  'Slovene'  'Spanish'  'Swedish'  'Turkish'  'Udmurt'  \
# 352         0          0          0          0          0         0
# 756         0          0          0          0          0         0
# 296         0          0          0          0          0         0
# 197         0          0          0          0          0         0
# 318         0          0          0          0          0         0
# 980         0          0          0          0          0         0
# 584         0          0          0          0          0         0
# 39          0          0          0          0          0         0
# 906         0          0          0          0          0         0
# 875         0          0          0          0          0         0
#
#      'Ukrainian'  'Viennese'  'Vorarlbergish'  'Võro'
# 352            0           0                0       0
# 756            0           0                0       0
# 296            0           0                0       0
# 197            0           0                0       0
# 318            0           0                0       0
# 980            0           0                0       0
# 584            0           0                0       0
# 39             0           0                0       0
# 906            0           0                0       0
# 875            0           0                0       0
#
# [10 rows x 1588 columns]
