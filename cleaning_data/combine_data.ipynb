# %%
import pandas as pd

# %%
world_data = pd.read_csv("../data/world_bank/combined_world_data.csv")
# eurovision_data = pd.read_csv("../data/eurovision/cleansed_eurovision_data.csv")
eurovision_data = pd.read_csv("../data/eurovision/eurovision_not_exploded_data.csv")

# %%
world_data.sample(10)
# Out:
#       index Country Name Country Code  Year  \
# 870      48       Latvia          LVA  2008
# 1034     18      Ireland          IRL  1978
# 1505     60        Italy          ITA  2020
# 388      42      Georgia          GEO  2002
# 1321     51     Slovenia          SVN  2011
# 292      19       France          FRA  1979
# 1828     34      Armenia          ARM  1994
# 1409     54     Bulgaria          BGR  2014
# 537      56  Netherlands          NLD  2016
# 1135     39    Lithuania          LTU  1999
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 870                                               100.0
# 1034                                                NaN
# 1505                                              100.0
# 388                                                48.8
# 1321                                              100.0
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                               100.0
# 1135                                                NaN
#
#       Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 870                                               100.0
# 1034                                                NaN
# 1505                                              100.0
# 388                                                11.0
# 1321                                              100.0
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                               100.0
# 1135                                                NaN
#
#       Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 870                                               100.0
# 1034                                                NaN
# 1505                                              100.0
# 388                                                86.6
# 1321                                              100.0
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                               100.0
# 1135                                                NaN
#
#       Access to electricity (% of population)  \
# 870                                      99.7
# 1034                                      NaN
# 1505                                    100.0
# 388                                      99.9
# 1321                                    100.0
# 292                                       NaN
# 1828                                      NaN
# 1409                                     95.9
# 537                                     100.0
# 1135                                    100.0
#
#       Access to electricity, rural (% of rural population)  \
# 870                                                99.9
# 1034                                                NaN
# 1505                                              100.0
# 388                                                99.8
# 1321                                              100.0
# 292                                                 NaN
# 1828                                                NaN
# 1409                                               90.7
# 537                                               100.0
# 1135                                              100.0
#
#       Access to electricity, urban (% of urban population)  ...  \
# 870                                                99.6     ...
# 1034                                                NaN     ...
# 1505                                              100.0     ...
# 388                                               100.0     ...
# 1321                                              100.0     ...
# 292                                                 NaN     ...
# 1828                                                NaN     ...
# 1409                                               97.8     ...
# 537                                               100.0     ...
# 1135                                              100.0     ...
#
#       People with basic handwashing facilities including soap and water, urban (% of urban population)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Risk premium on lending (lending rate minus treasury bill rate, %)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                           2.533167
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                           7.048458
# 537                                                 NaN
# 1135                                                NaN
#
#       Incidence of malaria (per 1,000 population at risk)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                           11.671715
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Net financial flows, RDB concessional (NFL, current US$)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Financial intermediary services indirectly Measured (FISIM) (constant LCU)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Net financial flows, IMF concessional (NFL, current US$)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Newborns protected against tetanus (%)  \
# 870                                      NaN
# 1034                                     NaN
# 1505                                     NaN
# 388                                      NaN
# 1321                                     NaN
# 292                                      NaN
# 1828                                     NaN
# 1409                                     NaN
# 537                                      NaN
# 1135                                     NaN
#
#       Net official flows from UN agencies, UNWTO (current US$)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
#       Use of insecticide-treated bed nets (% of under-5 population)
# 870                                                 NaN
# 1034                                                NaN
# 1505                                                NaN
# 388                                                 NaN
# 1321                                                NaN
# 292                                                 NaN
# 1828                                                NaN
# 1409                                                NaN
# 537                                                 NaN
# 1135                                                NaN
#
# [10 rows x 1489 columns]

# %%
eurovision_data.sample(10)
# Out:
#       Unnamed: 0                         Song  \
# 1004        1017                   Alvedansen
# 359          372                    Happy Man
# 341          354                 Questo amore
# 1224        1237                        I Can
# 1165        1178                     Run Away
# 1535        1548                         Stay
# 739          752                 Keelatud maa
# 672          685  Kinek mondjam el vétkeimet?
# 1623        1677              In corpore sano
# 535          548        Þú og þeir (Sókrates)
#
#                                Artist         Country  Year  \
# 1004           Christine Guldbrandsen          Norway  2006
# 359                      Cathal Dunne         Ireland  1979
# 341                   Ricchi e Poveri           Italy  1978
# 1224                             Blue  United Kingdom  2011
# 1165  SunStroke Project and Olia Tira         Moldova  2010
# 1535                    Anna Odobescu         Moldova  2019
# 739                  Maarja-Liis Ilus         Estonia  1997
# 672                   Friderika Bayer         Hungary  1994
# 1623                       Konstrakta          Serbia  2022
# 535                         Beathoven         Iceland  1988
#
#                   Language  Grand Final Place  Grand Final Points  Semifinal  \
# 1004         ['Norwegian']               14.0                36.0        NaN
# 359            ['English']                5.0                80.0        NaN
# 341            ['Italian']               12.0                53.0        NaN
# 1224           ['English']               11.0               100.0        NaN
# 1165           ['English']               22.0                27.0        1.0
# 1535           ['English']                NaN                 NaN        2.0
# 739           ['Estonian']                8.0                82.0        NaN
# 672          ['Hungarian']                4.0               122.0        NaN
# 1623  ['Serbian', 'Latin']                5.0               312.0        2.0
# 535          ['Icelandic']               16.0                20.0        NaN
#
#       Semifinal Place  Semifinal Points
# 1004              NaN               NaN
# 359               NaN               NaN
# 341               NaN               NaN
# 1224              NaN               NaN
# 1165             10.0              52.0
# 1535             12.0              85.0
# 739               NaN               NaN
# 672               NaN               NaN
# 1623              3.0             237.0
# 535               NaN               NaN

# %%
eurovision_countries = eurovision_data["Country"].unique()
world_countries = world_data["Country Name"].unique()

# %%
for country in eurovision_countries:
    if country not in world_data["Country Name"].unique():
        print(country)
# Out:
# Monaco
# Yugoslavia
# Turkey
# Russia
# Slovakia
# Serbia and Montenegro
# Czech Republic

# %%
for country in world_countries:
    if country not in eurovision_countries:
        print(country)
# Out:
# Russian Federation
# Slovak Republic
# Czechia
# Turkiye

# %%
eurovision_data["Country"].replace({"Czech Republic": "Czechia", "Russia": "Russian Federation", "Slovakia": "Slovak Republic", "Turkey": "Turkiye"}, inplace=True)
# Out:
# /var/folders/kl/zs51p_z135905dzchw5f3n480000gp/T/ipykernel_76664/796732920.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   eurovision_data["Country"].replace({"Czech Republic": "Czechia", "Russia": "Russian Federation", "Slovakia": "Slovak Republic", "Turkey": "Turkiye"}, inplace=True)

# %%
eurovision_data.rename(columns={"Country": "Country Name"}, inplace=True)

# %%
merged_df = pd.merge(eurovision_data, world_data, on=['Country Name', 'Year'], how='inner').reset_index()

# %%
first_cols = ['Country Name', 'Country Code', 'Year', "Song", "Artist", "Language", "Grand Final Place", "Grand Final Points", "Semifinal", "Semifinal Place", "Semifinal Points"]
remaining_cols = [col for col in merged_df.columns if col not in first_cols]
new_col_order = first_cols + remaining_cols

# %%
merged_df = merged_df[new_col_order]

# %%
merged_df.columns[:15]
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Song', 'Artist', 'Language',
#        'Grand Final Place', 'Grand Final Points', 'Semifinal',
#        'Semifinal Place', 'Semifinal Points', 'level_0', 'Unnamed: 0', 'index',
#        'Access to clean fuels and technologies for cooking (% of population)'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Columns: 1499 entries, Country Name to Use of insecticide-treated bed nets (% of under-5 population)
# dtypes: float64(1490), int64(4), object(5)
# memory usage: 16.1+ MB

# %%
merged_df.to_csv("../data/combined_data.csv", index=False)
